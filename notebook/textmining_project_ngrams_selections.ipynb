# %%
import numpy as np
import pandas as pd
import spacy
import nltk
from nltk.stem import WordNetLemmatizer
import os
import string
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import words
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import gensim.downloader as api
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
blogdf = pd.read_csv('/content/drive/MyDrive/text_mining_project/naturalscience/attempt2.csv')

words = pd.read_csv('/content/drive/MyDrive/text_mining_project/naturalscience/facktermer_naturvetenskap.csv')

# %%
class Selecting_ngrams: 
  def __init__(self, blogposts): 
    # här sparar jag alla n-grams 
    self.twogram_dict={}  
    self.blogposts = blogposts 

  def store_two_grams(self):  
    self.twogramdict = { }
    newngramdict = {} 
    def ngrams(wordlist): 
      ngramlist = [(wordlist[l],wordlist[l+1])   for l in range(LW-1)] 
      for ngram in ngramlist: 
        if ngram not in self.twogram_dict:
          self.twogram_dict[ngram] = 1
        else: 
          self.twogram_dict[ngram] += 1

    for blogs in self.blogposts: 
      wordlist = blogs.split() 
      LW = len(wordlist)
      if LW > 2: 
        ngrams(wordlist)

  def popular_two_grams(self, number): 
      newdict = { }
      for k, v in self.twogram_dict.items(): 
        if v > number: 
          newdict[k] = v

      sorted_dictionary = sorted(self.twogram_dict.items(), key=lambda x: x[1], reverse=True)  

      return sorted_dictionary

# %%
biologi_blogs = blogdf['cleaned_Comments'].dropna(how='all')

model1 = Selecting_ngrams(biologi_blogs)

model1.store_two_grams( )

ngramdict = model1.popular_two_grams(number=3)

ngramdict
# Out:
# [(('look', 'like'), 184),
#  (('alan', 'alan'), 143),
#  (('amino', 'acid'), 93),
#  (('make', 'sense'), 77),
#  (('dark', 'matter'), 68),
#  (('sound', 'like'), 62),
#  (('http', 'http'), 61),
#  (('seems', 'like'), 56),
#  (('year', 'ago'), 54),
#  (('something', 'like'), 52),
#  (('pretty', 'much'), 51),
#  (('feel', 'like'), 50),
#  (('immune', 'system'), 48),
#  (('grad', 'school'), 47),
#  (('assassin', 'bug'), 46),
#  (('thing', 'like'), 45),
#  (('make', 'sure'), 43),
#  (('you', 'could'), 43),
#  (('answer', 'question'), 42),
#  (('carbon', 'capture'), 41),
#  (('speed', 'light'), 41),
#  (('ice', 'cream'), 40),
#  (('high', 'school'), 39),
#  (('for', 'example'), 38),
#  (('thank', 'much'), 38),
#  (('mrna', 'vaccine'), 37),
#  (('would', 'say'), 37),
#  (('kinetic', 'energy'), 36),
#  (('good', 'luck'), 36),
#  (('even', 'though'), 33),
#  (('you', 'need'), 33),
#  (('wheel', 'bug'), 31),
#  (('organic', 'chemistry'), 31),
#  (('pretty', 'sure'), 30),
#  (('air', 'resistance'), 29),
#  (('quantum', 'mechanic'), 29),
#  (('lone', 'pair'), 28),
#  (('not', 'sure'), 28),
#  (('something', 'else'), 28),
#  (('sterile', 'neutrino'), 27),
#  (('many', 'people'), 27),
#  (('amanita', 'muscaria'), 27),
#  (('lot', 'people'), 27),
#  (('would', 'need'), 26),
#  (('reference', 'frame'), 26),
#  (('amount', 'energy'), 25),
#  (('light', 'source'), 25),
#  (('would', 'like'), 24),
#  (('magic', 'mushroom'), 24),
#  (('either', 'way'), 24),
#  (('would', 'take'), 24),
#  (('would', 'also'), 24),
#  (('carbon', 'dioxide'), 24),
#  (('the', 'problem'), 22),
#  (('natural', 'gas'), 22),
#  (('boric', 'acid'), 22),
#  (('would', 'get'), 22),
#  (('spike', 'protein'), 22),
#  (('much', 'better'), 21),
#  (('the', 'first'), 21),
#  (('want', 'know'), 21),
#  (('good', 'idea'), 21),
#  (('co2', 'atmosphere'), 21),
#  (('get', 'rid'), 21),
#  (('would', 'probably'), 21),
#  (('blood', 'cell'), 21),
#  (('would', 'see'), 21),
#  (('there', 'also'), 20),
#  (('would', 'make'), 20),
#  (('energy', 'required'), 20),
#  (('one', 'thing'), 20),
#  (('know', 'much'), 20),
#  (('magnetic', 'field'), 20),
#  (('what', 'mean'), 20),
#  (('one', 'side'), 20),
#  (('could', 'also'), 20),
#  (('small', 'amount'), 20),
#  (('bullet', 'away'), 20),
#  (('immune', 'response'), 19),
#  (('need', 'know'), 19),
#  (('every', 'day'), 19),
#  (('oxidation', 'state'), 19),
#  (('black', 'hole'), 19),
#  (('long', 'time'), 19),
#  (('first', 'time'), 19),
#  (('year', 'old'), 19),
#  (('some', 'people'), 19),
#  (('fly', 'agaric'), 19),
#  (('why', 'would'), 19),
#  (('long', 'covid'), 19),
#  (('side', 'effect'), 19),
#  (('long', 'term'), 19),
#  (('see', 'bullet'), 19),
#  (('you', 'probably'), 18),
#  (('job', 'market'), 18),
#  (('also', 'know'), 18),
#  (('pretty', 'good'), 18),
#  (('first', 'place'), 18),
#  (('really', 'good'), 18),
#  (('standard', 'model'), 18),
#  (('fossil', 'fuel'), 18),
#  (('many', 'time'), 18),
#  (('keep', 'mind'), 18),
#  (('someone', 'else'), 18),
#  (('acetic', 'acid'), 18),
#  (('there', 'lot'), 18),
#  (('you', 'might'), 17),
#  (('covid', 'vaccine'), 17),
#  (('new', 'one'), 17),
#  (('let', 'know'), 17),
#  (('make', 'lot'), 17),
#  (('dont', 'know'), 17),
#  (('would', 'change'), 17),
#  (('different', 'type'), 17),
#  (('one', 'way'), 17),
#  (('try', 'get'), 17),
#  (('like', 'would'), 17),
#  (('living', 'thing'), 17),
#  (('would', 'work'), 17),
#  (('bullet', 'travel'), 17),
#  (('http', 'opt'), 17),
#  (('even', 'know'), 16),
#  (('you', 'get'), 16),
#  (('million', 'year'), 16),
#  (('first', 'one'), 16),
#  (('chemical', 'reaction'), 16),
#  (('little', 'bit'), 16),
#  (('could', 'use'), 16),
#  (('like', 'one'), 16),
#  (('let', 'say'), 16),
#  (('think', 'would'), 16),
#  (('dry', 'ice'), 16),
#  (('you', 'also'), 16),
#  (('really', 'interesting'), 16),
#  (('the', 'thing'), 16),
#  (('would', 'still'), 16),
#  (('you', 'see'), 16),
#  (('breast', 'milk'), 16),
#  (('copper', 'sulfate'), 16),
#  (('would', 'recommend'), 16),
#  (('this', 'would'), 15),
#  (('covalent', 'bond'), 15),
#  (('surface', 'area'), 15),
#  (('much', 'time'), 15),
#  (('last', 'year'), 15),
#  (('isopropyl', 'alcohol'), 15),
#  (('neutron', 'decay'), 15),
#  (('people', 'know'), 15),
#  (('really', 'want'), 15),
#  (('could', 'get'), 15),
#  (('one', 'electron'), 15),
#  (('melting', 'point'), 15),
#  (('prairie', 'dog'), 15),
#  (('much', 'much'), 15),
#  (('far', 'know'), 15),
#  (('peer', 'review'), 15),
#  (('could', 'make'), 15),
#  (('second', 'law'), 15),
#  (('want', 'get'), 15),
#  (('nervous', 'system'), 15),
#  (('sure', 'would'), 14),
#  (('first', 'year'), 14),
#  (('would', 'likely'), 14),
#  (('would', 'able'), 14),
#  (('need', 'get'), 14),
#  (('anything', 'else'), 14),
#  (('much', 'like'), 14),
#  (('particle', 'physic'), 14),
#  (('thanks', 'lot'), 14),
#  (('trying', 'get'), 14),
#  (('real', 'life'), 14),
#  (('air', 'capture'), 14),
#  (('best', 'way'), 14),
#  (('everything', 'else'), 14),
#  (('half', 'life'), 14),
#  (('would', 'really'), 14),
#  (('might', 'want'), 14),
#  (('many', 'different'), 14),
#  (('probably', 'going'), 14),
#  (('the', 'way'), 14),
#  (('one', 'two'), 14),
#  (('think', 'could'), 14),
#  (('wave', 'function'), 14),
#  (('able', 'get'), 14),
#  (('opt', 'out'), 14),
#  (('observer', 'see'), 14),
#  (('really', 'need'), 13),
#  (('would', 'mean'), 13),
#  (('stuff', 'like'), 13),
#  (('space', 'time'), 13),
#  (('there', 'many'), 13),
#  (('really', 'know'), 13),
#  (('others', 'said'), 13),
#  (('much', 'energy'), 13),
#  (('direct', 'air'), 13),
#  (('study', 'physic'), 13),
#  (('correct', 'answer'), 13),
#  (('like', 'said'), 13),
#  (('come', 'back'), 13),
#  (('people', 'like'), 13),
#  (('would', 'happen'), 13),
#  (('next', 'time'), 13),
#  (('trying', 'make'), 13),
#  (('hydrogen', 'bond'), 13),
#  (('cardiac', 'arrest'), 13),
#  (('would', 'much'), 13),
#  (('strawberry', 'ice'), 13),
#  (('get', 'job'), 13),
#  (('every', 'time'), 13),
#  (('order', 'magnitude'), 13),
#  (('you', 'want'), 13),
#  (('could', 'help'), 13),
#  (('that', 'said'), 13),
#  (('could', 'try'), 13),
#  (('essential', 'amino'), 13),
#  (('period', 'time'), 13),
#  (('amount', 'time'), 13),
#  (('would', 'want'), 13),
#  (('seem', 'like'), 13),
#  (('anyone', 'else'), 13),
#  (('heart', 'disease'), 13),
#  (('square', 'root'), 13),
#  (('for', 'instance'), 12),
#  (('take', 'time'), 12),
#  (('noble', 'gas'), 12),
#  (('asking', 'question'), 12),
#  (('also', 'need'), 12),
#  (('this', 'make'), 12),
#  (('dragon', 'fly'), 12),
#  (('you', 'right'), 12),
#  (('one', 'one'), 12),
#  (('raw', 'data'), 12),
#  (('could', 'find'), 12),
#  (('that', 'would'), 12),
#  (('human', 'body'), 12),
#  (('month', 'ago'), 12),
#  (('completely', 'different'), 12),
#  (('think', 'thing'), 12),
#  (('number', 'atom'), 12),
#  (('room', 'temperature'), 12),
#  (('dark', 'energy'), 12),
#  (('opposite', 'direction'), 12),
#  (('you', 'know'), 12),
#  (('organic', 'synthesis'), 12),
#  (('tertiary', 'structure'), 12),
#  (('people', 'get'), 12),
#  (('time', 'dilation'), 12),
#  (('different', 'thing'), 12),
#  (('think', 'people'), 12),
#  (('think', 'might'), 12),
#  (('force', 'gravity'), 12),
#  (('would', 'look'), 12),
#  (('people', 'would'), 12),
#  (('immune', 'cell'), 12),
#  (('interference', 'pattern'), 12),
#  (('solar', 'system'), 12),
#  (('system', 'would'), 12),
#  (('link', 'http'), 12),
#  (('physic', 'degree'), 12),
#  (('find', 'way'), 11),
#  (('double', 'slit'), 11),
#  (('may', 'also'), 11),
#  (('general', 'relativity'), 11),
#  (('point', 'view'), 11),
#  (('almost', 'certainly'), 11),
#  (('common', 'cold'), 11),
#  (('good', 'job'), 11),
#  (('stupid', 'question'), 11),
#  (('neutron', 'star'), 11),
#  (('different', 'way'), 11),
#  (('atom', 'molecule'), 11),
#  (('the', 'energy'), 11),
#  (('smell', 'like'), 11),
#  (('capture', 'carbon'), 11),
#  (('lot', 'thing'), 11),
#  (('normal', 'force'), 11),
#  (('still', 'get'), 11),
#  (('energy', 'cost'), 11),
#  (('the', 'one'), 11),
#  (('personal', 'experience'), 11),
#  (('might', 'able'), 11),
#  (('scientific', 'community'), 11),
#  (('power', 'plant'), 11),
#  (('high', 'pressure'), 11),
#  (('end', 'life'), 11),
#  (('that', 'make'), 11),
#  (('would', 'never'), 11),
#  (('way', 'around'), 11),
#  (('question', 'would'), 11),
#  (('homework', 'problem'), 11),
#  (('brand', 'new'), 11),
#  (('north', 'america'), 11),
#  (('the', 'bullet'), 11),
#  (('thought', 'would'), 11),
#  (('ask', 'question'), 11),
#  (('this', 'mean'), 11),
#  (('one', 'would'), 11),
#  (('cell', 'would'), 11),
#  (('there', 'nothing'), 11),
#  (('emergent', 'property'), 11),
#  (('surface', 'tension'), 11),
#  (('thing', 'could'), 11),
#  (('time', 'time'), 11),
#  (('what', 'would'), 11),
#  (('away', 'first'), 11),
#  (('first', 'light'), 11),
#  (('quantum', 'system'), 11),
#  (('valence', 'electron'), 10),
#  (('this', 'guy'), 10),
#  (('want', 'work'), 10),
#  (('you', 'got'), 10),
#  (('not', 'really'), 10),
#  (('what', 'kind'), 10),
#  (('nuclear', 'reactor'), 10),
#  (('spend', 'time'), 10),
#  (('the', 'fact'), 10),
#  (('wood', 'frog'), 10),
#  (('one', 'could'), 10),
#  (('little', 'one'), 10),
#  (('energy', 'source'), 10),
#  (('conjoined', 'twin'), 10),
#  (('journal', 'article'), 10),
#  (('get', 'high'), 10),
#  (('chlorine', 'gas'), 10),
#  (('make', 'good'), 10),
#  (('required', 'capture'), 10),
#  (('making', 'sure'), 10),
#  (('water', 'bottle'), 10),
#  (('right', 'direction'), 10),
#  (('chemistry', 'major'), 10),
#  (('but', 'think'), 10),
#  (('that', 'mean'), 10),
#  (('would', 'better'), 10),
#  (('make', 'feel'), 10),
#  (('phd', 'student'), 10),
#  (('thing', 'would'), 10),
#  (('second', 'bullet'), 10),
#  (('couple', 'year'), 10),
#  (('body', 'would'), 10),
#  (('way', 'would'), 10),
#  (('one', 'time'), 10),
#  (('force', 'acting'), 10),
#  (('high', 'enough'), 10),
#  (('you', 'make'), 10),
#  (('wave', 'drag'), 10),
#  (('red', 'blood'), 10),
#  (('two', 'different'), 10),
#  (('vocal', 'pitch'), 10),
#  (('never', 'get'), 10),
#  (('pretty', 'bad'), 10),
#  (('and', 'also'), 10),
#  (('they', 'also'), 10),
#  (('entry', 'level'), 10),
#  (('beep', 'boop'), 10),
#  (('would', 'expect'), 10),
#  (('electron', 'transport'), 10),
#  (('would', 'think'), 10),
#  (('help', 'lot'), 10),
#  (('amount', 'protein'), 10),
#  (('could', 'potentially'), 10),
#  (('hydrogen', 'atom'), 10),
#  (('also', 'cause'), 10),
#  (('new', 'physic'), 10),
#  (('gravitational', 'field'), 10),
#  (('many', 'thing'), 10),
#  (('looked', 'like'), 10),
#  (('this', 'one'), 10),
#  (('would', 'good'), 10),
#  (('way', 'get'), 10),
#  (('going', 'get'), 10),
#  (('good', 'thing'), 10),
#  (('light', 'bullet'), 10),
#  (('maybe', 'try'), 10),
#  (('want', 'make'), 10),
#  (('two', 'week'), 10),
#  (('short', 'answer'), 10),
#  (('deeper', 'voice'), 10),
#  (('might', 'get'), 10),
#  (('short', 'time'), 10),
#  (('fuel', 'rod'), 10),
#  (('every', 'year'), 9),
#  (('would', 'definitely'), 9),
#  (('that', 'sound'), 9),
#  (('would', 'love'), 9),
#  (('slit', 'experiment'), 9),
#  (('want', 'take'), 9),
#  (('you', 'find'), 9),
#  (('get', 'enough'), 9),
#  (('weak', 'acid'), 9),
#  (('also', 'make'), 9),
#  (('also', 'think'), 9),
#  (('gen', 'chem'), 9),
#  (('virus', 'cause'), 9),
#  (('law', 'physic'), 9),
#  (('speed', 'limit'), 9),
#  (('two', 'thing'), 9),
#  (('periodic', 'table'), 9),
#  (('never', 'said'), 9),
#  (('the', 'mrna'), 9),
#  (('wash', 'hand'), 9),
#  (('gon', 'say'), 9),
#  (('would', 'use'), 9),
#  (('energy', 'would'), 9),
#  (('know', 'nothing'), 9),
#  (('capture', 'co2'), 9),
#  (('guess', 'would'), 9),
#  (('could', 'say'), 9),
#  (('much', 'easier'), 9),
#  (('crystal', 'structure'), 9),
#  (('nuclear', 'power'), 9),
#  (('life', 'cycle'), 9),
#  (('thought', 'experiment'), 9),
#  (('force', 'applied'), 9),
#  (('back', 'time'), 9),
#  (('nitric', 'acid'), 9),
#  (('http', 'good'), 9),
#  (('people', 'see'), 9),
#  (('want', 'learn'), 9),
#  (('time', 'saw'), 9),
#  (('energy', 'come'), 9),
#  (('active', 'ingredient'), 9),
#  (('need', 'add'), 9),
#  (('lot', 'stuff'), 9),
#  (('one', 'like'), 9),
#  (('gravitational', 'pull'), 9),
#  (('atomic', 'clock'), 9),
#  (('common', 'ancestor'), 9),
#  (('good', 'place'), 9),
#  (('system', 'the'), 9),
#  (('rabbit', 'hole'), 9),
#  (('but', 'also'), 9),
#  (('part', 'body'), 9),
#  (('pair', 'electron'), 9),
#  (('get', 'good'), 9),
#  (('transport', 'chain'), 9),
#  (('who', 'know'), 9),
#  (('never', 'seen'), 9),
#  (('how', 'many'), 9),
#  (('time', 'move'), 9),
#  (('back', 'forth'), 9),
#  (('next', 'year'), 9),
#  (('classical', 'mechanic'), 9),
#  (('want', 'see'), 9),
#  (('hope', 'help'), 9),
#  (('could', 'see'), 9),
#  (('github', 'http'), 9),
#  (('travel', 'time'), 9),
#  (('good', 'reason'), 9),
#  (('cause', 'death'), 9),
#  (('travel', 'speed'), 9),
#  (('gravitational', 'force'), 9),
#  (('tilt', 'right'), 9),
#  (('great', 'deal'), 9),
#  (('even', 'get'), 9),
#  (('aluminum', 'oxide'), 9),
#  (('people', 'think'), 9),
#  (('you', 'put'), 9),
#  (('vast', 'majority'), 9),
#  (('sodium', 'chloride'), 9),
#  (('think', 'right'), 9),
#  (('never', 'know'), 9),
#  (('never', 'heard'), 9),
#  (('someone', 'could'), 9),
#  (('water', 'would'), 9),
#  (('like', 'know'), 9),
#  (('potential', 'energy'), 9),
#  (('paper', 'http'), 9),
#  (('need', 'lot'), 9),
#  (('get', 'really'), 9),
#  (('your', 'body'), 9),
#  (('away', 'observer'), 9),
#  (('stem', 'cell'), 9),
#  (('baking', 'soda'), 8),
#  (('you', 'really'), 8),
#  (('oxygen', 'water'), 8),
#  (('get', 'one'), 8),
#  (('could', 'wrong'), 8),
#  (('time', 'hand'), 8),
#  (('they', 'live'), 8),
#  (('rotor', 'wash'), 8),
#  (('question', 'could'), 8),
#  (('multiple', 'light'), 8),
#  (('you', 'would'), 8),
#  (('amount', 'water'), 8),
#  (('somewhere', 'else'), 8),
#  (('know', 'enough'), 8),
#  (('food', 'grade'), 8),
#  (('many', 'many'), 8),
#  (('literally', 'one'), 8),
#  (('scientific', 'research'), 8),
#  (('lot', 'water'), 8),
#  (('everyone', 'else'), 8),
#  (('say', 'anything'), 8),
#  (('really', 'matter'), 8),
#  (('know', 'many'), 8),
#  (('field', 'theory'), 8),
#  (('also', 'say'), 8),
#  (('starting', 'point'), 8),
#  (('energy', 'released'), 8),
#  (('energy', 'gained'), 8),
#  (('really', 'well'), 8),
#  (('mutation', 'rate'), 8),
#  (('commonly', 'used'), 8),
#  (('office', 'hour'), 8),
#  (('even', 'think'), 8),
#  (('say', 'something'), 8),
#  (('going', 'much'), 8),
#  (('like', 'saying'), 8),
#  (('live', 'long'), 8),
#  (('lot', 'different'), 8),
#  (('people', 'want'), 8),
#  (('act', 'like'), 8),
#  (('event', 'horizon'), 8),
#  (('hurt', 'like'), 8),
#  (('much', 'chemistry'), 8),
#  (('this', 'way'), 8),
#  (('would', 'put'), 8),
#  (('http', 'found'), 8),
#  (('the', 'reason'), 8),
#  (('billion', 'year'), 8),
#  (('slightly', 'different'), 8),
#  (('really', 'fast'), 8),
#  (('without', 'knowing'), 8),
#  (('come', 'across'), 8),
#  (('one', 'body'), 8),
#  (('hydrofluoric', 'acid'), 8),
#  (('get', 'back'), 8),
#  (('actually', 'make'), 8),
#  (('know', 'lot'), 8),
#  (('make', 'easier'), 8),
#  (('know', 'people'), 8),
#  (('lipid', 'nanoparticles'), 8),
#  (('wear', 'mask'), 8),
#  (('water', 'content'), 8),
#  (('constant', 'speed'), 8),
#  (('dead', 'body'), 8),
#  (('tap', 'water'), 8),
#  (('health', 'issue'), 8),
#  (('local', 'doctor'), 8),
#  (('make', 'new'), 8),
#  (('you', 'may'), 8),
#  (('one', 'need'), 8),
#  (('machine', 'learning'), 8),
#  (('testosterone', 'level'), 8),
#  (('viral', 'genome'), 8),
#  (('main', 'reason'), 8),
#  (('thing', 'even'), 8),
#  (('something', 'similar'), 8),
#  (('google', 'search'), 8),
#  (('physical', 'chemistry'), 8),
#  (('you', 'mean'), 8),
#  (('info', 'http'), 8),
#  (('left', 'side'), 8),
#  (('rubbing', 'alcohol'), 8),
#  (('need', 'understand'), 8),
#  (('digesting', 'food'), 8),
#  (('also', 'look'), 8),
#  (('way', 'think'), 8),
#  (('solve', 'problem'), 8),
#  (('sure', 'know'), 8),
#  (('matter', 'much'), 8),
#  (('matter', 'dark'), 8),
#  (('total', 'drag'), 8),
#  (('make', 'much'), 8),
#  (('really', 'understand'), 8),
#  (('whole', 'thing'), 8),
#  (('but', 'still'), 8),
#  (('straight', 'line'), 8),
#  (('also', 'see'), 8),
#  (('ibotenic', 'acid'), 8),
#  (('year', 'back'), 8),
#  (('cotton', 'candy'), 8),
#  (('first', 'thought'), 8),
#  (('the', 'main'), 8),
#  (('heat', 'transfer'), 8),
#  (('long', 'take'), 8),
#  (('lab', 'work'), 8),
#  (('like', 'animal'), 8),
#  (('engineering', 'degree'), 8),
#  (('please', 'read'), 8),
#  (('unit', 'cell'), 8),
#  (('end', 'day'), 8),
#  (('condensed', 'matter'), 8),
#  (('producing', 'foreign'), 8),
#  (('cell', 'cell'), 8),
#  (('you', 'think'), 8),
#  (('acid', 'form'), 8),
#  (('could', 'easily'), 8),
#  (('hard', 'water'), 8),
#  (('climate', 'change'), 8),
#  (('gravitational', 'potential'), 8),
#  (('good', 'know'), 8),
#  (('like', 'hell'), 8),
#  (('help', 'get'), 8),
#  (('really', 'like'), 8),
#  (('law', 'thermodynamics'), 8),
#  (('octet', 'rule'), 8),
#  (('would', 'keep'), 8),
#  (('cause', 'cancer'), 8),
#  (('rest', 'body'), 8),
#  (('fun', 'fact'), 8),
#  (('you', 'use'), 8),
#  (('energy', 'density'), 8),
#  (('200', 'year'), 8),
#  (('would', 'try'), 8),
#  (('lot', 'energy'), 8),
#  (('best', 'bet'), 8),
#  (('producing', 'spike'), 8),
#  (('time', 'year'), 7),
#  (('way', 'detect'), 7),
#  (('one', 'day'), 7),
#  (('first', 'two'), 7),
#  (('good', 'faith'), 7),
#  (('this', 'may'), 7),
#  (('forbidden', 'strawberry'), 7),
#  (('dissolve', 'water'), 7),
#  (('taste', 'like'), 7),
#  (('work', 'well'), 7),
#  (('this', 'correct'), 7),
#  (('trying', 'find'), 7),
#  (('would', 'cause'), 7),
#  (('also', 'work'), 7),
#  (('already', 'know'), 7),
#  (('use', 'something'), 7),
#  (('read', 'paper'), 7),
#  (('last', 'one'), 7),
#  (('thought', 'process'), 7),
#  (('something', 'need'), 7),
#  (('would', 'one'), 7),
#  (('way', 'could'), 7),
#  (('oxidation', 'number'), 7),
#  (('first', 'sentence'), 7),
#  (('spray', 'bottle'), 7),
#  (('problem', 'solving'), 7),
#  (('would', 'give'), 7),
#  (('cell', 'body'), 7),
#  (('know', 'know'), 7),
#  (('get', 'close'), 7),
#  (('quantum', 'field'), 7),
#  (('giant', 'squid'), 7),
#  (('maillard', 'reaction'), 7),
#  (('make', 'antibody'), 7),
#  (('perpetual', 'motion'), 7),
#  (('may', 'may'), 7),
#  (('review', 'article'), 7),
#  (('amount', 'co2'), 7),
#  (('research', 'group'), 7),
#  (('you', 'going'), 7),
#  (('going', 'need'), 7),
#  (('try', 'make'), 7),
#  (('ionic', 'compound'), 7),
#  (('analytical', 'chemistry'), 7),
#  (('chemistry', 'degree'), 7),
#  (('whole', 'new'), 7),
#  (('advanced', 'degree'), 7),
#  (('get', 'better'), 7),
#  (('would', 'help'), 7),
#  (('long', 'enough'), 7),
#  (('the', 'issue'), 7),
#  (('bio', 'major'), 7),
#  (('another', 'one'), 7),
#  (('think', 'much'), 7),
#  (('sulfuric', 'acid'), 7),
#  (('the', 'job'), 7),
#  (('point', 'really'), 7),
#  (('get', 'vaccinated'), 7),
#  (('someone', 'would'), 7),
#  (('readily', 'available'), 7),
#  (('probably', 'want'), 7),
#  (('high', 'low'), 7),
#  (('would', 'break'), 7),
#  (('see', 'doctor'), 7),
#  (('electron', 'universe'), 7),
#  (('people', 'seem'), 7),
#  (('very', 'interesting'), 7),
#  (('video', 'http'), 7),
#  (('cause', 'problem'), 7),
#  (('concentration', 'water'), 7),
#  (('lot', 'easier'), 7),
#  (('couple', 'time'), 7),
#  (('molar', 'mass'), 7),
#  (('pretty', 'neat'), 7),
#  (('love', 'see'), 7),
#  (('feel', 'free'), 7),
#  (('uncertainty', 'principle'), 7),
#  (('chemistry', 'lab'), 7),
#  (('could', 'happen'), 7),
#  (('let', 'alone'), 7),
#  (('people', 'say'), 7),
#  (('sqrt', 'sqrt'), 7),
#  (('conflict', 'interest'), 7),
#  (('cancer', 'remission'), 7),
#  (('anything', 'but'), 7),
#  (('good', 'way'), 7),
#  (('medicinal', 'chemistry'), 7),
#  (('here', 'http'), 7),
#  (('could', 'take'), 7),
#  (('hydrogen', 'peroxide'), 7),
#  (('ever', 'seen'), 7),
#  (('thanks', 'reply'), 7),
#  (('google', 'scholar'), 7),
#  (('time', 'you'), 7),
#  (('others', 'mentioned'), 7),
#  (('organic', 'chemist'), 7),
#  (('theoretically', 'possible'), 7),
#  (('best', 'guess'), 7),
#  (('get', 'started'), 7),
#  (('have', 'tried'), 7),
#  (('heavy', 'element'), 7),
#  (('might', 'need'), 7),
#  (('exactly', 'like'), 7),
#  (('post', 'like'), 7),
#  (('place', 'start'), 7),
#  (('one', 'end'), 7),
#  (('science', 'class'), 7),
#  (('the', 'kind'), 7),
#  (('much', 'larger'), 7),
#  (('generate', 'energy'), 7),
#  (('finding', 'job'), 7),
#  (('global', 'warming'), 7),
#  (('living', 'organism'), 7),
#  (('need', 'help'), 7),
#  (('find', 'something'), 7),
#  (('get', 'much'), 7),
#  (('please', 'explain'), 7),
#  (('hard', 'say'), 7),
#  (('nowhere', 'near'), 7),
#  (('make', 'think'), 7),
#  (('computational', 'chemistry'), 7),
#  (('time', 'would'), 7),
#  (('air', 'pressure'), 7),
#  (('quite', 'bit'), 7),
#  (('kind', 'like'), 7),
#  (('read', 'book'), 7),
#  (('inorganic', 'chemistry'), 7),
#  (('centripetal', 'force'), 7),
#  (('generating', 'energy'), 7),
#  (('constant', 'acceleration'), 7),
#  (('bot', 'swapp'), 7),
#  (('swapp', 'thy'), 7),
#  (('thy', 'word'), 7),
#  (('word', 'shakespeare'), 7),
#  (('shakespeare', 'word'), 7),
#  (('word', 'shakespeareinsult'), 7),
#  (('shakespeareinsult', 'fordo'), 7),
#  (('fordo', 'optout'), 7),
#  (('viscous', 'drag'), 7),
#  (('large', 'scale'), 7),
#  (('thing', 'people'), 7),
#  (('make', 'money'), 7),
#  (('pretty', 'interesting'), 7),
#  (('quantum', 'physic'), 7),
#  (('would', 'suggest'), 7),
#  (('really', 'appreciate'), 7),
#  (('weak', 'interaction'), 7),
#  (('frame', 'reference'), 7),
#  (('central', 'atom'), 7),
#  (('neutron', 'capture'), 7),
#  (('long', 'way'), 7),
#  (('mean', 'could'), 7),
#  (('master', 'degree'), 7),
#  (('health', 'risk'), 7),
#  (('ever', 'since'), 7),
#  (('something', 'new'), 7),
#  (('tree', 'life'), 7),
#  (('there', 'way'), 7),
#  (('the', 'amount'), 7),
#  (('high', 'level'), 7),
#  (('quantum', 'computer'), 7),
#  (('carbon', 'monoxide'), 7),
#  (('etc', 'etc'), 7),
#  (('copper', 'chloride'), 7),
#  (('travel', 'faster'), 7),
#  (('faster', 'light'), 7),
#  (('like', 'year'), 7),
#  (('bodily', 'fluid'), 7),
#  (('thing', 'really'), 7),
#  (('when', 'say'), 7),
#  (('free', 'energy'), 7),
#  (('salt', 'water'), 7),
#  (('really', 'depends'), 7),
#  (('good', 'question'), 7),
#  (('natural', 'immunity'), 7),
#  (('like', 'good'), 7),
#  (('also', 'get'), 7),
#  (('get', 'sick'), 7),
#  (('lot', 'sense'), 7),
#  (('special', 'case'), 7),
#  (('good', 'example'), 7),
#  (('pretty', 'well'), 7),
#  (('head', 'around'), 7),
#  (('drinking', 'water'), 7),
#  (('nobel', 'prize'), 7),
#  (('anything', 'like'), 7),
#  (('would', 'know'), 7),
#  (('fatty', 'acid'), 7),
#  (('got', 'one'), 7),
#  (('one', 'really'), 7),
#  (('may', 'better'), 7),
#  (('past', 'year'), 7),
#  (('the', 'second'), 7),
#  (('last', 'month'), 7),
#  (('like', 'people'), 7),
#  (('make', 'mrna'), 7),
#  (('something', 'wrong'), 7),
#  (('comp', 'sci'), 7),
#  (('enough', 'get'), 7),
#  (('life', 'even'), 7),
#  (('would', 'rather'), 7),
#  (('not', 'want'), 7),
#  (('chemical', 'engineering'), 7),
#  (('bullet', 'hit'), 7),
#  (('doe', 'make'), 7),
#  (('ascorbic', 'acid'), 7),
#  (('cue', 'card'), 7),
#  (('learn', 'something'), 7),
#  (('adverse', 'effect'), 7),
#  (('out', 'http'), 7),
#  (('out', 'subreddit'), 7),
#  (('subreddit', 'http'), 7),
#  (('http', 'github'), 7),
#  (('http', 'downvote'), 7),
#  (('downvote', 'remove'), 7),
#  (('youtube', 'channel'), 7),
#  (('time', 'reversal'), 7),
#  (('bad', 'idea'), 7),
#  (('trying', 'figure'), 7),
#  (('would', 'start'), 7),
#  (('co2', 'emission'), 7),
#  (('would', 'guess'), 7),
#  (('mean', 'think'), 7),
#  (('homework', 'question'), 7),
#  (('higgs', 'boson'), 7),
#  (('like', 'use'), 7),
#  (('might', 'also'), 7),
#  (('question', 'answer'), 7),
#  (('dark', 'sector'), 7),
#  (('energy', 'level'), 7),
#  (('uranium', 'nitride'), 7),
#  (('cross', 'section'), 7),
#  (('heart', 'attack'), 7),
#  (('want', 'believe'), 7),
#  (('nail', 'polish'), 7),
#  (('neurological', 'long'), 7),
#  (('large', 'enough'), 6),
#  (('far', 'aware'), 6),
#  (('probably', 'get'), 6),
#  (('are', 'sure'), 6),
#  (('sharing', 'data'), 6),
#  (('quantum', 'eraser'), 6),
#  (('molecular', 'formula'), 6),
#  (('scientific', 'method'), 6),
#  (('along', 'line'), 6),
#  (('good', 'start'), 6),
#  (('really', 'bad'), 6),
#  (('strong', 'acid'), 6),
#  (('yes', 'think'), 6),
#  (('weight', 'left'), 6),
#  (('would', 'super'), 6),
#  (('really', 'mean'), 6),
#  (('biology', 'degree'), 6),
#  (('probably', 'need'), 6),
#  (('know', 'everything'), 6),
#  (('often', 'used'), 6),
#  (('neutrino', 'oscillate'), 6),
#  (('higgs', 'field'), 6),
#  (('right', 'handed'), 6),
#  (('this', 'common'), 6),
#  (('came', 'say'), 6),
#  (('immunity', 'one'), 6),
#  (('different', 'mode'), 6),
#  (('actually', 'pretty'), 6),
#  (('animal', 'grow'), 6),
#  (('family', 'doctor'), 6),
#  (('heavy', 'metal'), 6),
#  (('currently', 'working'), 6),
#  (('twin', 'head'), 6),
#  (('idea', 'thank'), 6),
#  (('never', 'actually'), 6),
#  (('still', 'lot'), 6),
#  (('hydrochloric', 'acid'), 6),
#  (('probably', 'would'), 6),
#  (('make', 'people'), 6),
#  (('look', 'similar'), 6),
#  (('first', 'hand'), 6),
#  (('know', 'well'), 6),
#  (('produce', 'antibody'), 6),
#  (('still', 'say'), 6),
#  (('think', 'understand'), 6),
#  (('would', 'required'), 6),
#  (('actually', 'know'), 6),
#  (('time', 'ago'), 6),
#  (('matter', 'efficient'), 6),
#  (('bottle', 'water'), 6),
#  (('that', 'pretty'), 6),
#  (('entirely', 'different'), 6),
#  (('people', 'believe'), 6),
#  (('most', 'people'), 6),
#  (('research', 'field'), 6),
#  (('vice', 'versa'), 6),
#  (('people', 'make'), 6),
#  (('neutron', 'proton'), 6),
#  (('able', 'use'), 6),
#  (('would', 'kill'), 6),
#  (('need', 'something'), 6),
#  (('couple', 'day'), 6),
#  (('know', 'one'), 6),
#  (('could', 'always'), 6),
#  (('nile', 'red'), 6),
#  (('you', 'try'), 6),
#  (('work', 'fine'), 6),
#  (('really', 'big'), 6),
#  (('physical', 'law'), 6),
#  (('know', 'mechanism'), 6),
#  (('one', 'another'), 6),
#  (('lepton', 'universality'), 6),
#  (('like', 'probably'), 6),
#  (('electromagnetic', 'field'), 6),
#  (('quantum', 'mechanical'), 6),
#  (('morphologically', 'similar'), 6),
#  (('hundred', 'million'), 6),
#  (('island', 'stability'), 6),
#  (('super', 'heavy'), 6),
#  (('much', 'bigger'), 6),
#  (('air', 'plant'), 6),
#  (('like', 'the'), 6),
#  (('really', 'think'), 6),
#  (('protein', 'body'), 6),
#  (('angular', 'momentum'), 6),
#  (('small', 'molecule'), 6),
#  (('small', 'enough'), 6),
#  (('small', 'particle'), 6),
#  (('like', 'nitrogen'), 6),
#  (('time', 'see'), 6),
#  (('water', 'concentration'), 6),
#  (('way', 'control'), 6),
#  (('getting', 'downvoted'), 6),
#  (('two', 'year'), 6),
#  (('forbidden', 'ice'), 6),
#  (('kill', 'bacteria'), 6),
#  (('thing', 'the'), 6),
#  (('that', 'interesting'), 6),
#  (('probably', 'much'), 6),
#  (('people', 'use'), 6),
#  (('wear', 'glove'), 6),
#  (('one', 'step'), 6),
#  (('would', 'possible'), 6),
#  (('assasin', 'bug'), 6),
#  (('better', 'answer'), 6),
#  (('weird', 'thing'), 6),
#  (('really', 'wish'), 6),
#  (('enter', 'every'), 6),
#  (('every', 'cell'), 6),
#  (('mrna', 'get'), 6),
#  (('made', 'cell'), 6),
#  (('going', 'around'), 6),
#  (('people', 'feel'), 6),
#  (('the', 'force'), 6),
#  (('new', 'particle'), 6),
#  (('short', 'life'), 6),
#  (('reverse', 'transcriptase'), 6),
#  (('hardware', 'store'), 6),
#  (('but', 'know'), 6),
#  (('cell', 'this'), 6),
#  (('the', 'virus'), 6),
#  (('host', 'cell'), 6),
#  (('failed', 'virus'), 6),
#  (('this', 'true'), 6),
#  (('like', 'think'), 6),
#  (('year', 'later'), 6),
#  (('easy', 'get'), 6),
#  (('sure', 'mean'), 6),
#  (('mean', 'something'), 6),
#  (('whole', 'lot'), 6),
#  (('because', 'would'), 6),
#  (('last', 'day'), 6),
#  (('time', 'get'), 6),
#  (('take', 'longer'), 6),
#  (('real', 'world'), 6),
#  (('really', 'cool'), 6),
#  (('going', 'able'), 6),
#  (('dark', 'skin'), 6),
#  (('darker', 'skin'), 6),
#  (('aluminium', 'oxide'), 6),
#  (('that', 'one'), 6),
#  (('able', 'find'), 6),
#  (('try', 'find'), 6),
#  (('tiny', 'bit'), 6),
#  (('asking', 'help'), 6),
#  (('watch', 'video'), 6),
#  (('work', 'like'), 6),
#  (('would', 'certainly'), 6),
#  (('hard', 'time'), 6),
#  (('good', 'one'), 6),
#  (('probably', 'best'), 6),
#  (('phd', 'position'), 6),
#  (('one', 'main'), 6),
#  (('way', 'make'), 6),
#  (('wanted', 'know'), 6),
#  (('would', 'eat'), 6),
#  ...]
